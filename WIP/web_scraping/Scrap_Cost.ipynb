# %%
from bs4 import BeautifulSoup
import requests

# %%
year = '2016'
make = 'cadillac'
model = 'ats'
submodel = ''
parts = 'bumpers'

url = "https://www.carid.com/"+year+"-"+make+"-"+model+"-"+parts+"/"
print(url)
# Out:
# https://www.carid.com/2016-cadillac-ats-bumpers/

# %%
# response = requests.get('https://www.napaautocare.com/estimator.aspx')
# soup = BeautifulSoup(response.text,"lxml")

response = requests.get(url)
soup = BeautifulSoup(response.text,"lxml")

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html class="no-js desktop" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>2016 Cadillac ATS Replacement Bumpers &amp; Components – CARiD.com</title>
# ...

# %%
soup.title()
# Out:
# []

# %%
all_spans = soup.find_all("span")
all_spans
# Out:
# [<span class="left-menu-icon js-hamburger" data-flag-src="https://cdn.carid.com/css/flags/US-small.svg" data-has-mmy="1" data-store-id="1" data-toggle-class="left-panel-show" data-vehicle-garage-id="15" data-vehicle-id="15"></span>,
#  <span class="js-nav-tool-title -txt -arrow -without-content">Garage</span>,
#  <span class="icon -icon-garage"><span class="count-item -type-1 js-my-garage-counter"></span></span>,
#  <span class="count-item -type-1 js-my-garage-counter"></span>,
#  <span class="icon -icon-wishlist"><span class="count-item -type-1 js-wishlist-counter hidden"></span></span>,
#  <span class="count-item -type-1 js-wishlist-counter hidden"></span>,
#  <span class="acc-text">Shopping Cart</span>,
#  <span class="icon -icon-cart"><span class="count-item -type-1 hidden js-mini-cart-total-items"></span></span>,
#  <span class="count-item -type-1 hidden js-mini-cart-total-items"></span>,
#  <span class="js-nav-tool-title -txt -arrow">My Account</span>,
# ...

# %%
all_prices = soup.find_all('span',{'class':'lst_prc'} )
all_prices
# Out:
# [<span class="lst_prc">$251.51 - $558.63</span>,
#  <span class="lst_prc">$251.51 - $592.02</span>,
#  <span class="lst_prc">$198.59 - $199.53</span>,
#  <span class="lst_prc">$109.45 - $276.54</span>,
#  <span class="lst_prc">$141.65 - $182.68</span>,
#  <span class="lst_prc">$103.34</span>,
#  <span class="lst_prc">$109.15 - $126.01</span>,
#  <span class="lst_prc">$130.14</span>,
#  <span class="lst_prc">$69.28</span>,
#  <span class="lst_prc">$79.05</span>,
#  <span class="lst_prc">$8.57 - $9.89</span>,
#  <span class="lst_prc">$9.59 - $11.75</span>,
#  <span class="lst_prc">$12.75</span>,
#  <span class="lst_prc">$110.78</span>,
#  <span class="lst_prc">$88.57</span>,
#  <span class="lst_prc">$101.31</span>,
#  <span class="lst_prc">$225.97</span>,
#  <span class="lst_prc">$23.66 - $24.68</span>,
#  <span class="lst_prc">$193.75</span>,
#  <span class="lst_prc">$462.40</span>,
#  <span class="lst_prc">$76.61 - $124.89</span>,
#  <span class="lst_prc">$59.95 - $99.95</span>,
# ...

# %%
import numpy as np

cost = []
for price in all_prices:
    #cost.append (price.get('$'))
    cost+=(str(price.string).replace('$','').replace(' ','').replace(',','').split('-'))
        
print(cost)

cost_int = [float(c) for c in cost]

mean_cost = np.mean(cost_int)

big_cost = [c for c in cost_int if c >= mean_cost]

mean_big_cost = np.mean(big_cost)

mean_big_cost
# Out:
# ['251.51', '558.63', '251.51', '592.02', '198.59', '199.53', '109.45', '276.54', '141.65', '182.68', '103.34', '109.15', '126.01', '130.14', '69.28', '79.05', '8.57', '9.89', '9.59', '11.75', '12.75', '110.78', '88.57', '101.31', '225.97', '23.66', '24.68', '193.75', '462.40', '76.61', '124.89', '59.95', '99.95', '19.95', '80.00', '150.00', '234.00', '251.10', '198.00', '159.00', '279.00', '279.00', '279.00', '279.00', '279.00', '90.00', '67.15', '67.15', '87.55', '90.00', '101.15', '101.15', '101.15', '101.15', '101.15', '44.99', '34.99', '54.99', '35.00', '36.87', '67.62', '96.36', '396.95', '895.90', '1341.30', '646.85', '19.95', '16.11', '17.94', '22.09', '253.51', '257.37', '145.65', '189.33', '7.46']
# 363.55538461538464
